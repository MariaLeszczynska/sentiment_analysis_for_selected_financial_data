# %%
import sys
sys.path.append("../src")

from sector_specific_sentiment import build_all_sector_datasets

# %%
build_all_sector_datasets()
# Out:
# Saved XLE (headline-level) to: ..\data\preprocessed\final\xle.csv
# Saved XLF (headline-level) to: ..\data\preprocessed\final\xlf.csv
# Saved XLK (headline-level) to: ..\data\preprocessed\final\xlk.csv
# Saved XLV (headline-level) to: ..\data\preprocessed\final\xlv.csv
# Saved XLY (headline-level) to: ..\data\preprocessed\final\xly.csv
