# %% [markdown]
# ### Making sure the format of all the sector stock prices formats is the same

# %%
import sys
sys.path.append("../src")

from stock_prices import preprocess_file, RAW_DIR
from pathlib import Path

csv_files = list(RAW_DIR.glob("*_prices.csv"))
csv_files

outputs = [preprocess_file(path) for path in csv_files]
