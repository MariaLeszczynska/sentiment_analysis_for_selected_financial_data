# %%
import pandas as pd

# %%
df1 = pd.read_parquet("../data/preprocessed/bloomberg_reuters.016.parquet")
df1.head(10)
# Out:
#                    date                                               text  \
# 0  2016-02-05T00:00:00Z      Canada's BCE posts lower profit, ups dividend
# 1  2016-02-05T00:00:00Z  BRIEF-Zealand Pharma clarifies its role in US ...
# 2  2016-02-05T00:00:00Z  Fitch: Mixed Creditor Implications From New Tu...
# 3  2016-02-05T00:00:00Z  BRIEF-S&T; sees FY Smart Energy segment sales ...
# 4  2016-02-05T00:00:00Z  AstraZeneca CEO open for deals that pay from d...
# 5  2016-02-05T00:00:00Z  COLUMN-Gender pay gap can haunt women even in ...
# 6  2016-02-05T00:00:00Z  UPDATE 1-CITIC Securities says executives retu...
# 7  2016-02-05T00:00:00Z  UPDATE 1-Kyrgyzstan may sue Centerra Gold over...
# 8  2016-02-05T00:00:00Z  Continental says Daimler, Fiat Chrysler, Honda...
# 9  2016-02-05T00:00:00Z  Red Cross delivers food, medicine to besieged ...
#
#                                         extra_fields
# 0  {"date_raw":"2016-02-05","date_trading":"2016-...
# ...

# %%
df1 = pd.read_parquet("../data/preprocessed/finsen_us_2007_2023.000.parquet")
df1.head(10)
# Out:
#                    date                                               text  \
# 0  2007-06-04T00:00:00Z  Blackstone boosts IPO after Beijing takes $3bn...
# 1  2007-06-04T00:00:00Z  Trade Deficit Increases in March 2007\n\nTrade...
# 2  2007-06-06T00:00:00Z  Consumer Price Index 2.6 percent higher than i...
# 3  2007-06-06T00:00:00Z  Nonfarm payroll employment increased by 157,00...
# 4  2007-06-06T00:00:00Z  U.S. Federal Reserve Kept Rates Unchanged at 5...
# 5  2007-06-06T00:00:00Z  United States GDP Rises 0.6 percent in the fir...
# 6  2007-06-06T00:00:00Z  United States Trade Balance Deficit Rises to $...
# 7  2007-06-21T00:00:00Z  US Economy is expanding after Q1 slowdown\n\nU...
# 8  2007-06-24T00:00:00Z  The Fed is widely expected to keep the benchma...
# 9  2007-06-26T00:00:00Z  Consumer Confidence and Housing Weaken in US\n...
#
#                                         extra_fields
# 0  {"category":"Other","date_raw":"4/06/2007","da...
# ...

# %%
df1.tail(10)
# Out:
#                        date  \
# 15513  2023-07-15T00:00:00Z
# 15514  2023-07-15T00:00:00Z
# 15515  2023-07-15T00:00:00Z
# 15516  2023-07-15T00:00:00Z
# 15517  2023-07-15T00:00:00Z
# 15518  2023-07-15T00:00:00Z
# 15519  2023-07-15T00:00:00Z
# 15520  2023-07-15T00:00:00Z
# 15521  2023-07-15T00:00:00Z
# 15522  2023-07-16T00:00:00Z
#
#                                                     text  \
# 15513  JPMorgan Hits 16-month High\n\nJPMorgan Hits 1...
# 15514  US Export Prices Fall More than Expected\n\nUS...
# 15515  US Treasury Yields Below Recent Highs\n\nUS Tr...
# 15516  Wells Fargo earnings above expectations at 1.2...
# 15517  BlackRock earnings above expectations at 9.28 ...
# 15518  UnitedHealth earnings above expectations at 6....
# 15519  Dollar Languishes on Dovish Fed Bets\n\nDollar...
# 15520  Bitcoin Climbs as US Inflation Slows\n\nBitcoi...
# 15521  Citigroup earnings above expectations at 1.37 ...
# 15522  TSX Slightly Down, Books Weekly Gains\n\nTSX S...
#
# ...
