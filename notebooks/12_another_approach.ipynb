# %%
import pandas as pd

# %%
df = pd.read_csv("../data/preprocessed/All_external.csv")
df.head()
# Out:
# C:\Users\maria\AppData\Local\Temp\ipykernel_5336\4127414112.py:1: DtypeWarning: Columns (2,4,5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/preprocessed/All_external.csv")
#                       Date                                      Article_title  \
# 0  2020-06-05 06:30:54 UTC            Stocks That Hit 52-Week Highs On Friday
# 1  2020-06-03 06:45:20 UTC         Stocks That Hit 52-Week Highs On Wednesday
# 2  2020-05-26 00:30:07 UTC                      71 Biggest Movers From Friday
# 3  2020-05-22 08:45:06 UTC       46 Stocks Moving In Friday's Mid-Day Session
# 4  2020-05-22 07:38:59 UTC  B of A Securities Maintains Neutral on Agilent...
#
#   Stock_symbol                                                Url  \
# 0            A  https://www.benzinga.com/news/20/06/16190091/s...
# 1            A  https://www.benzinga.com/news/20/06/16170189/s...
# 2            A  https://www.benzinga.com/news/20/05/16103463/7...
# ...

# %%
df.shape
# Out:
# (13057514, 11)

# %%
df.isna().sum()
# Out:
# Date                       0
# Article_title              1
# Stock_symbol         9804627
# Url                      686
# Publisher            9030871
# Author              11871199
# Article             11809202
# Lsa_summary         13057514
# Luhn_summary        13057514
# Textrank_summary    13057514
# Lexrank_summary     13057514
# dtype: int64

# %%
df.nunique()
# Out:
# Date                 2795203
# Article_title        9541041
# Stock_symbol            6619
# Url                 11565422
# Publisher               1142
# Author                 37000
# Article              1243362
# Lsa_summary                0
# Luhn_summary               0
# Textrank_summary           0
# Lexrank_summary            0
# dtype: int64

# %%
df = pd.read_csv("../data/preprocessed/nasdaq_exteral_data.csv")
df.head()
# Out:
# C:\Users\maria\AppData\Local\Temp\ipykernel_5336\3137932498.py:1: DtypeWarning: Columns (3,5,6,7,8,9,10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/preprocessed/nasdaq_exteral_data.csv")
#    Unnamed: 0                     Date  \
# 0         0.0  2023-12-16 23:00:00 UTC
# 1         1.0  2023-12-12 00:00:00 UTC
# 2         2.0  2023-12-12 00:00:00 UTC
# 3         3.0  2023-12-07 00:00:00 UTC
# 4         4.0  2023-12-07 00:00:00 UTC
#
#                                        Article_title Stock_symbol  \
# 0  Interesting A Put And Call Options For August ...            A
# 1  Wolfe Research Initiates Coverage of Agilent T...            A
# 2  Agilent Technologies Reaches Analyst Target Price            A
# 3  Agilent (A) Enhances BioTek Cytation C10 With ...            A
# 4  Pre-Market Most Active for Dec 7, 2023 : SQQQ,...            A
#
#                                                  Url Publisher Author  \
# ...
